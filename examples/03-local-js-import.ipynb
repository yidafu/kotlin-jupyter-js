// %% [markdown]
// # 08 - Importing Local JavaScript Files
//
// ## Learning Objectives
// - Learn how to import local JavaScript files in Kotlin Jupyter JS
// - Understand different import syntaxes for local modules
// - Master the usage of relative and absolute paths
// - Learn how to work with default and named exports
//
// ## Prerequisites
// - Basic understanding of ES6 modules
// - Familiarity with import/export syntax
// - Knowledge of file paths (relative vs absolute)
//
// ## Difficulty: ⭐⭐☆☆☆
//
// ## Core Concept
//
// Kotlin Jupyter JS supports importing local JavaScript files using standard ES6 module syntax. You can use:
// - **Relative paths**: `./local.js`, `../utils/helper.js`
// - **Absolute paths**: `/path/to/file.js`
//
// The system will automatically:
// 1. Detect local file imports (paths starting with `.` or `/`)
// 2. Read the file content
// 3. Transform it into an inline module
// 4. Make exports available to your code

// %%
// 🔧 Load the Kotlin Jupyter JS library
USE {
    repositories {
        mavenLocal()
        mavenCentral()
    }
    dependencies {
        implementation("dev.yidafu.jupyter:jupyter-js:0.8.0")
    }
}

// %% [markdown]
// ## Step 1: Prepare Local JavaScript File
//
// First, let's check what's available in our `local.js` file. This file contains various export patterns:
//
// ```javascript
// // Named exports
// export const foo = 123;
// export function functionName() { }
// export class ClassName { }
//
// // Export with aliases
// const var3 = true;
// const var4 = {}
// export { var3, var4 as obj }
//
// // Destructured exports
// const obj = {a: 1, b: 2};
// export const { a, b: c } = obj;
//
// // Default export
// export default class Xxx { }
// ```

// %% [markdown]
// ## Step 2: Import Named Exports
//
// ### 2.1 Import Specific Named Exports

// %%
%js

// Import specific named exports from local file
import { foo, functionName, ClassName } from './local.js';

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            📦 Named Exports from local.js
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <p><strong>foo value:</strong> <span style="color: #e74c3c;">${foo}</span></p>
            <p><strong>functionName type:</strong> <span style="color: #3498db;">${typeof functionName}</span></p>
            <p><strong>ClassName type:</strong> <span style="color: #9b59b6;">${typeof ClassName}</span></p>
        </div>
    </div>
`;

console.log('Imported from local.js:', { foo, functionName, ClassName });
// Out:
// <div id="58b522f3-ac5f-4161-922f-8c884f80733e" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("58b522f3-ac5f-4161-922f-8c884f80733e");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const foo = inline_Li9sb2NhbC5qcw.foo;
// const functionName = inline_Li9sb2NhbC5qcw.functionName;
// const ClassName = inline_Li9sb2NhbC5qcw.ClassName;
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             📦 Named Exports from local.js
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <p><strong>foo value:</strong> <span style="color: #e74c3c;">${foo}</span></p>
//             <p><strong>functionName type:</strong> <span style="color: #3498db;">${typeof functionName}</span></p>
//             <p><strong>ClassName type:</strong> <span style="color: #9b59b6;">${typeof ClassName}</span></p>
//         </div>
//     </div>
// `;
// console.log('Imported from local.js:', {
//     foo,
//     functionName,
//     ClassName
// });
//
// </script>

// %% [markdown]
// ### 2.2 Import Aliased Exports

// %%
%js

// Import exports with aliases
import { var3, obj } from './local.js';

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            🏷️ Aliased Exports
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <p><strong>var3:</strong> <span style="color: #27ae60;">${var3}</span></p>
            <p><strong>obj (alias for var4):</strong> <span style="color: #e67e22;">${JSON.stringify(obj)}</span></p>
        </div>
    </div>
`;

console.log('Aliased exports:', { var3, obj });
// Out:
// <div id="06e69459-cfc1-470b-b02a-10392229b58c" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("06e69459-cfc1-470b-b02a-10392229b58c");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const var3 = inline_Li9sb2NhbC5qcw.var3;
// const obj = inline_Li9sb2NhbC5qcw.obj;
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             🏷️ Aliased Exports
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <p><strong>var3:</strong> <span style="color: #27ae60;">${var3}</span></p>
//             <p><strong>obj (alias for var4):</strong> <span style="color: #e67e22;">${JSON.stringify(obj)}</span></p>
//         </div>
//     </div>
// `;
// console.log('Aliased exports:', {
//     var3,
//     obj
// });
//
// </script>

// %% [markdown]
// ### 2.3 Import Destructured Exports

// %%
%js

// Import destructured exports
import { a, c } from './local.js';

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            🔀 Destructured Exports
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <p><strong>a:</strong> <span style="color: #3498db;">${a}</span></p>
            <p><strong>c (renamed from b):</strong> <span style="color: #e74c3c;">${c}</span></p>
        </div>
    </div>
`;

console.log('Destructured exports:', { a, c });
// Out:
// <div id="df600083-a14b-4197-94fb-0e6319560afa" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("df600083-a14b-4197-94fb-0e6319560afa");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const a = inline_Li9sb2NhbC5qcw.a;
// const c = inline_Li9sb2NhbC5qcw.c;
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             🔀 Destructured Exports
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <p><strong>a:</strong> <span style="color: #3498db;">${a}</span></p>
//             <p><strong>c (renamed from b):</strong> <span style="color: #e74c3c;">${c}</span></p>
//         </div>
//     </div>
// `;
// console.log('Destructured exports:', {
//     a,
//     c
// });
//
// </script>

// %% [markdown]
// ## Step 3: Import Default Export
//
// ### 3.1 Import Default Export

// %%
%js

// Import default export
import DefaultClass from './local.js';

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            ⭐ Default Export
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <p><strong>Default export type:</strong> <span style="color: #9b59b6;">${typeof DefaultClass}</span></p>
            <p><strong>Is it a class?:</strong> <span style="color: #27ae60;">${typeof DefaultClass === 'function' ? 'Yes' : 'No'}</span></p>
        </div>
    </div>
`;

console.log('Default export:', DefaultClass);
// Out:
// <div id="6f6e0305-c286-4246-af5c-b76c4e9e1675" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("6f6e0305-c286-4246-af5c-b76c4e9e1675");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const DefaultClass = inline_Li9sb2NhbC5qcw.default;
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             ⭐ Default Export
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <p><strong>Default export type:</strong> <span style="color: #9b59b6;">${typeof DefaultClass}</span></p>
//             <p><strong>Is it a class?:</strong> <span style="color: #27ae60;">${typeof DefaultClass === 'function' ? 'Yes' : 'No'}</span></p>
//         </div>
//     </div>
// `;
// console.log('Default export:', DefaultClass);
//
// </script>

// %% [markdown]
// ### 3.2 Import Default and Named Exports Together

// %%
%js

// Import both default and named exports
import DefaultClass, { foo, functionName, ClassName } from './local.js';

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            🎯 Mixed Imports (Default + Named)
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <h3 style="color: #34495e;">Default Export:</h3>
            <p><strong>DefaultClass:</strong> <span style="color: #9b59b6;">${typeof DefaultClass}</span></p>
            
            <h3 style="color: #34495e; margin-top: 15px;">Named Exports:</h3>
            <p><strong>foo:</strong> <span style="color: #e74c3c;">${foo}</span></p>
            <p><strong>functionName:</strong> <span style="color: #3498db;">${typeof functionName}</span></p>
            <p><strong>ClassName:</strong> <span style="color: #27ae60;">${typeof ClassName}</span></p>
        </div>
    </div>
`;

console.log('Mixed imports:', { DefaultClass, foo, functionName, ClassName });
// Out:
// <div id="d98168b3-41fc-424d-a569-43bf0fbac2eb" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("d98168b3-41fc-424d-a569-43bf0fbac2eb");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const DefaultClass = inline_Li9sb2NhbC5qcw.default;
// const foo = inline_Li9sb2NhbC5qcw.foo;
// const functionName = inline_Li9sb2NhbC5qcw.functionName;
// const ClassName = inline_Li9sb2NhbC5qcw.ClassName;
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             🎯 Mixed Imports (Default + Named)
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <h3 style="color: #34495e;">Default Export:</h3>
//             <p><strong>DefaultClass:</strong> <span style="color: #9b59b6;">${typeof DefaultClass}</span></p>
//
//             <h3 style="color: #34495e; margin-top: 15px;">Named Exports:</h3>
//             <p><strong>foo:</strong> <span style="color: #e74c3c;">${foo}</span></p>
//             <p><strong>functionName:</strong> <span style="color: #3498db;">${typeof functionName}</span></p>
//             <p><strong>ClassName:</strong> <span style="color: #27ae60;">${typeof ClassName}</span></p>
//         </div>
//     </div>
// `;
// console.log('Mixed imports:', {
//     DefaultClass,
//     foo,
//     functionName,
//     ClassName
// });
//
// </script>

// %% [markdown]
// ## Step 4: Import All Exports as Namespace
//
// ### 4.1 Import Everything as a Namespace Object

// %%
%js

// Import all exports as a namespace
import * as LocalModule from './local.js';

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            🌐 Namespace Import (import * as)
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <p><strong>LocalModule.foo:</strong> <span style="color: #e74c3c;">${LocalModule.foo}</span></p>
            <p><strong>LocalModule.var3:</strong> <span style="color: #27ae60;">${LocalModule.var3}</span></p>
            <p><strong>LocalModule.a:</strong> <span style="color: #3498db;">${LocalModule.a}</span></p>
            <p><strong>LocalModule.default:</strong> <span style="color: #9b59b6;">${typeof LocalModule.default}</span></p>
            <p><strong>Available exports:</strong> <span style="color: #e67e22;">${Object.keys(LocalModule).join(', ')}</span></p>
        </div>
    </div>
`;

console.log('Namespace import:', LocalModule);
console.log('All exported keys:', Object.keys(LocalModule));
// Out:
// <div id="77a8a6f0-07e2-4d0c-9db9-750a90734e5d" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("77a8a6f0-07e2-4d0c-9db9-750a90734e5d");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const LocalModule = inline_Li9sb2NhbC5qcw;
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             🌐 Namespace Import (import * as)
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <p><strong>LocalModule.foo:</strong> <span style="color: #e74c3c;">${LocalModule.foo}</span></p>
//             <p><strong>LocalModule.var3:</strong> <span style="color: #27ae60;">${LocalModule.var3}</span></p>
//             <p><strong>LocalModule.a:</strong> <span style="color: #3498db;">${LocalModule.a}</span></p>
//             <p><strong>LocalModule.default:</strong> <span style="color: #9b59b6;">${typeof LocalModule.default}</span></p>
//             <p><strong>Available exports:</strong> <span style="color: #e67e22;">${Object.keys(LocalModule).join(', ')}</span></p>
//         </div>
//     </div>
// `;
// console.log('Namespace import:', LocalModule);
// console.log('All exported keys:', Object.keys(LocalModule));
//
// </script>

// %% [markdown]
// ## Step 5: Using Imported Modules
//
// ### 5.1 Create Instance and Call Functions

// %%
%js

import DefaultClass, { foo, ClassName } from './local.js';

// Create instances
const instance1 = new DefaultClass();
const instance2 = new ClassName();

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            🎨 Using Imported Classes
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <h3 style="color: #34495e;">Class Instances:</h3>
            <p><strong>DefaultClass instance:</strong> <span style="color: #9b59b6;">${instance1.constructor.name}</span></p>
            <p><strong>ClassName instance:</strong> <span style="color: #27ae60;">${instance2.constructor.name}</span></p>
            
            <h3 style="color: #34495e; margin-top: 15px;">Using Values:</h3>
            <p><strong>foo * 2:</strong> <span style="color: #e74c3c;">${foo * 2}</span></p>
        </div>
    </div>
`;

console.log('Created instances:', { instance1, instance2 });
// Out:
// <div id="ec4dc466-4d67-4b82-944b-737e7d9d0d92" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("ec4dc466-4d67-4b82-944b-737e7d9d0d92");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const DefaultClass = inline_Li9sb2NhbC5qcw.default;
// const foo = inline_Li9sb2NhbC5qcw.foo;
// const ClassName = inline_Li9sb2NhbC5qcw.ClassName;
// const instance1 = new DefaultClass();
// const instance2 = new ClassName();
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             🎨 Using Imported Classes
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <h3 style="color: #34495e;">Class Instances:</h3>
//             <p><strong>DefaultClass instance:</strong> <span style="color: #9b59b6;">${instance1.constructor.name}</span></p>
//             <p><strong>ClassName instance:</strong> <span style="color: #27ae60;">${instance2.constructor.name}</span></p>
//
//             <h3 style="color: #34495e; margin-top: 15px;">Using Values:</h3>
//             <p><strong>foo * 2:</strong> <span style="color: #e74c3c;">${foo * 2}</span></p>
//         </div>
//     </div>
// `;
// console.log('Created instances:', {
//     instance1,
//     instance2
// });
//
// </script>

// %% [markdown]
// ## Step 6: Combining with Kotlin Data
//
// ### 6.1 Export Data from Kotlin

// %%
// Create Kotlin data
val multiplier = 5
val message = "Hello from Kotlin!"

println("✅ Kotlin data exported: multiplier=$multiplier, message='$message'")
// Out:
// ✅ Kotlin data exported: multiplier=5, message='Hello from Kotlin!'

// %% [markdown]
// ### 6.2 Use Both Kotlin Data and Local Module in JavaScript

// %%
%js

// Import from both local file and Kotlin
import { foo } from './local.js';
import { multiplier, message } from '@jupyter';

const result = foo * multiplier;

const container = getContainer();
container.innerHTML = `
    <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
        <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
            🔗 Combining Kotlin Data with Local Module
        </h2>
        
        <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
            <h3 style="color: #34495e;">From local.js:</h3>
            <p><strong>foo:</strong> <span style="color: #e74c3c;">${foo}</span></p>
            
            <h3 style="color: #34495e; margin-top: 15px;">From Kotlin:</h3>
            <p><strong>multiplier:</strong> <span style="color: #3498db;">${multiplier}</span></p>
            <p><strong>message:</strong> <span style="color: #27ae60;">${message}</span></p>
            
            <h3 style="color: #34495e; margin-top: 15px;">Combined Result:</h3>
            <p><strong>foo × multiplier:</strong> <span style="color: #9b59b6; font-size: 1.5em;">${result}</span></p>
        </div>
    </div>
`;

console.log('Combined data:', { foo, multiplier, message, result });
// Out:
// <div id="4f7d1dbd-4712-4e0f-be80-7ff0c3d97b38" style="width:100%;min-height:30px;max-height:400px"></div>
// <script type="module">
// function getContainer(width = "100%", height = "300px") {
//     var cellRoot = document.getElementById("4f7d1dbd-4712-4e0f-be80-7ff0c3d97b38");
//     cellRoot.style = `width: ${width};height: ${height}`
//     return cellRoot;
// }
//  const multiplier = 5 ;
// const message = "Hello from Kotlin!"
//  const global_Li9sb2NhbC5qcw = (function(exports = {}) {
//     console.log('local message');
//     const var3 = true;
//     const var4 = {};
//     const var5 = "default";
//     const obj = {
//         a: 1,
//         b: 2
//     };
//     const foo = 123;
//     exports.foo = foo;
//     function functionName() {}
//     exports.functionName = functionName;
//     class ClassName {
//     }
//     exports.ClassName = ClassName;
//     exports.var3 = var3;
//     exports.obj = var4;
//     exports.default = var5;
//     const { a, b: c } = obj;
//     exports.a = obj.a;
//     exports.c = c;
//     exports.default = "123";
//     exports.default = function() {};
//     exports.default = class Xxx {
//     };
//     return exports;
// })();
// const inline_Li9sb2NhbC5qcw = global_Li9sb2NhbC5qcw;
// const foo = inline_Li9sb2NhbC5qcw.foo;
// const result = foo * multiplier;
// const container = getContainer();
// container.innerHTML = `
//     <div style="padding: 20px; font-family: 'Segoe UI', sans-serif;">
//         <h2 style="color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 10px;">
//             🔗 Combining Kotlin Data with Local Module
//         </h2>
//
//         <div style="background: #ecf0f1; padding: 15px; border-radius: 8px; margin: 15px 0;">
//             <h3 style="color: #34495e;">From local.js:</h3>
//             <p><strong>foo:</strong> <span style="color: #e74c3c;">${foo}</span></p>
//
//             <h3 style="color: #34495e; margin-top: 15px;">From Kotlin:</h3>
//             <p><strong>multiplier:</strong> <span style="color: #3498db;">${multiplier}</span></p>
//             <p><strong>message:</strong> <span style="color: #27ae60;">${message}</span></p>
//
//             <h3 style="color: #34495e; margin-top: 15px;">Combined Result:</h3>
//             <p><strong>foo × multiplier:</strong> <span style="color: #9b59b6; font-size: 1.5em;">${result}</span></p>
//         </div>
//     </div>
// `;
// console.log('Combined data:', {
//     foo,
//     multiplier,
//     message,
//     result
// });
//
// </script>

// %% [markdown]
// ## Summary
//
// This example demonstrates comprehensive usage of local JavaScript file imports:
//
// 1. ✅ **Named Exports** - Import specific named exports using `import { name } from './file.js'`
// 2. ✅ **Aliased Exports** - Import exports with different names in the source file
// 3. ✅ **Destructured Exports** - Import destructured object properties
// 4. ✅ **Default Export** - Import default export using `import Name from './file.js'`
// 5. ✅ **Mixed Imports** - Combine default and named imports
// 6. ✅ **Namespace Import** - Import everything as namespace using `import * as Name`
// 7. ✅ **Integration** - Combine local modules with Kotlin data
//
// ### Key Points
//
// - Use **relative paths** (`./file.js`, `../dir/file.js`) for files in the same directory or parent directories
// - Use **absolute paths** (`/path/to/file.js`) when you know the full path
// - All standard ES6 import syntaxes are supported
// - Local files are automatically inlined and transformed
// - You can combine imports from local files and Kotlin (`@jupyter`) in the same cell
//
// ## Extension Exercises
//
// 1. Create your own local JavaScript module with utility functions
// 2. Try importing TypeScript files (`.ts`, `.tsx`)
// 3. Create a module that processes Kotlin data and re-exports it
// 4. Build a multi-file module system with dependencies between local files
// 5. Combine local modules with CDN libraries (like React, D3, etc.)
